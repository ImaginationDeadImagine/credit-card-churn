# %% [markdown]
# # **C3 Project Data Cleaning**

# %% [markdown]
# ## Objectives
#
# * Notebook objective: Clean raw data from Kaggle
#
# ## Inputs
#
# * BankChurners.csv file downloaded from [Kaggle](https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers) as .zip archive.
#
# ## Process
#
# * Unzip archive file from Kaggle to give BankChurners.csv file.  Place csv file in two directories, clean_data and raw_data.  The raw_data file will remain in the state it was after unzipping the archive file.
#
# * The clean_data file starts out the same as the raw_data file but is processed in a sequence of steps to generate the final cleaned file.  The steps are outlined below in the notebook.
#
# ## Outputs
#
# * At the end of the notebook a cleaned data file, BankChurners_clean.csv, is generated.
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# ## C3 Data Cleaning Process
#
# ### Data Setup

# %%
# Setup
import pandas as pd

df = pd.read_csv('../data/clean_data/BankChurners_clean.csv')
print(df.shape)
df.head()
# Out:
# (10127, 23)
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# ...

# %%
# Lesson: Use df.info(), df.describe(), and df.isna().sum() to map the damage.
# Try it:
#   Check the column names. Notice any spaces or weird capitalisation?
#   Print df.isna().sum() to see which columns have missing values.

# --- YOUR CODE ---
print(df.info())
print('=============================')
print(df.describe())
print('=============================')
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# The output confirms that the file contains 10,127 records.  Inspection of the output reveals that all variable names, except for CLIENTNUM, are written in CapWords, also known as PascalCase.  There are no obvious misspellings of any of the variable names.
